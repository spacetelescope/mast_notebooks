# %% [markdown]
# <a id="top"></a>
# # How to Organize Widgets with `motorcycle`
# ***
# ## Learning Goals
#
# This is a beginner tutorial on organizing widgets using [motorcycle](https://github.com/jupyter-widgets/jupyterlab-sidecar). We'll cover the basics of creating sidecars and managing their layout. By the end of this tutorial, you will:
#
# - Understand how to use motorcycle to control the sidecar layout.
# - Be able to create your own configuration of sidecars.
# - Know how to change motorcycle layouts to fit your preferences in the Roman Research Nexus (RRN).

# %% [markdown]
# ## Table of Contents
#
# ## Introduction

# %% [markdown]
# ## Imports
# We will leverage the `motorcycle` package to switch between predefined layouts of `sidecars`, and we will use `mast-aladin` and`jdaviz` to populate the sidecars with example widgets.
#
# - `motorcycle` to control the layout of sidecars
# - `sidecar` to create sidecars
# - `mast-aladin` for creating example widget to organize
# - `jdaviz` for creating example widget to organize

# %%
from sidecar import Sidecar
from ipywidgets import widgets
from astropy.coordinates import SkyCoord
import astropy.units as u

from mast_aladin import AppSidecar

# %% [markdown]
# ## Organizing Widgets with `motorcycle`
#
# ### Setup
# We will setup 3 different sidecar instances, two with viz, and one with a generic HTML to show off the different layouts that can be achieved.

# %%
# initialize mast-aladin and jdaviz in sidecars
mast_aladin, viz = AppSidecar.open()

# # center Aladin on NGC 5194
# mast_aladin.target = SkyCoord.from_name('Whirlpool Galaxy')
# mast_aladin.fov = 25 * u.arcmin

# # load a NIRCam image of NGC 5194 into jdaviz
# image_uri = "mast:jwst/products/jw01783003004_02101_00003_nrcblong_rate.fits"
# viz.load(image_uri, format='Image')
# plot_options = viz.plugins['Plot Options']
# plot_options.stretch_function = 'Arcsinh'
# plot_options.image_colormap = 'Magma'
# plot_options.stretch_preset = '99.5%'

with Sidecar(title='generic sidecar widget', anchor='split-right'):
    display(
        widgets.HTML(
            "<h2>generic sidecar widget</h2>"
        )
    )

# %% [markdown]
# ## About this Notebook
#
# **Author(s):** Patrick Custer <br>
# **Keyword(s):** motorcycle, sidecar, mast-aladin, jdaviz <br>
# **First published:** Aug 2026 <br>
# **Last updated:** Aug 2026 <br>
#
# ***
# [Top of Page](#top)
# <img style="float: right;" src="https://raw.githubusercontent.com/spacetelescope/style-guides/master/guides/images/stsci-logo.png" alt="Space Telescope Logo" width="200px"/>
